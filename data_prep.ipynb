# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cars_final_1.csv',index_col=0)

# %%
df.iloc[19:26,:]
# Out:
#           0             1                      2       3              4  \
# 19  1900000  Foreign Used                Saloons    Grey  2 Wheel Drive
# 20   128000  Locally Used                Saloons    Blue  2 Wheel Drive
# 21   128000  Locally Used                Saloons    Blue  2 Wheel Drive
# 22    60000  Foreign Used                Saloons    Grey         Petrol
# 23    60000  Foreign Used                Saloons  Silver         Petrol
# 24     1500  Foreign Used  4 Wheel Drives & SUVs   Black  4 Wheel Drive
# 25     1500  Foreign Used  4 Wheel Drives & SUVs   Black  4 Wheel Drive
#
#             5               6              7  \
# 19     Petrol  Lefthand Drive      Automatic
# 20     Petrol  Lefthand Drive      Automatic
# 21     Petrol  Lefthand Drive      Automatic
# 22  Automatic         Leather              4
# 23  Automatic         Leather    ₦5,100,000
# 24     Petrol  Lefthand Drive   ₦10,000,000
# 25     Petrol  Lefthand Drive      Automatic
#
# ...

# %%
df['10'] = df['10'].str.replace('\n', '')  #get the /n out of 10 column
df['9'] = df['9'].str.replace('\n', '')  #get the /n out of 10 column
df['10'] = df['10'].str.replace('Automatic', '')

#remove colors
df['10'] = df['10'].str.replace('Grey','')
df['10'] = df['10'].str.replace('Black','')
df['10'] = df['10'].str.replace('White','')
df['10'] = df['10'].str.replace('Maroon','')

data = pd.DataFrame()
data['make-year'] = df['10'].str[:4]    #set make year
data['automation'] = df['6']
data['price'] = df['9']
data['car-name'] = df['10'].str[4:]
data['color'] = df['2']

# %%
#setting specific contents

data.loc[13:16,'color'] = df.iloc[13:16,3]
data = data.drop([17],axis=0)

# %%
data.head(50)
# Out:
#    make-year      automation             price  \
# 0       2012       Automatic       ₦4,650,000
# 1       2004       Automatic       ₦1,950,000
# 2       2004       Automatic       ₦1,400,000
# 3       2011       Automatic       ₦2,400,000
# 4       2015       Automatic      ₦13,500,000
# 5       2006       Automatic       ₦3,000,000
# 6       2007       Automatic       ₦4,000,000
# 7       2008       Automatic         ₦880,000
# 8       2008       Automatic       ₦3,200,000
# 9       2008       Automatic       ₦1,750,000
# 10      2008       Automatic       ₦2,750,000
# 11      2010       Automatic       ₦2,050,000
# 12      2008       Automatic      ₦13,800,000
# 16      2008       Automatic       ₦4,500,000
# 18      2012       Automatic       ₦7,000,000
# 19      2012  Lefthand Drive                -
# 20      2004  Lefthand Drive                -
# 21      2004  Lefthand Drive         ₦650,000
# 22      2016         Leather       ₦5,500,000
# ...

# %%
df.iloc[13:20,5:]
# Out:
#                  5               6          7  \
# 13          Petrol  Lefthand Drive  Automatic
# 14       Automatic           Cloth        1.8
# 15       Automatic         Leather          4
# 16  Lefthand Drive       Automatic    Leather
# 17         Leather            2016         -
# 18  Lefthand Drive       Automatic    Leather
# 19          Petrol  Lefthand Drive  Automatic
#
#                                              8                 9  \
# 13                                       Cloth                -
# 14                                        2011                -
# 15                                        2014                -
# 16                                           4       ₦4,500,000
# 17  \n2016 Other Automatic Toyota Highlander\n  Electric Mirrors
# 18                                           4       ₦7,000,000
# 19                                     Leather                -
#
#                                   10  \
# ...
